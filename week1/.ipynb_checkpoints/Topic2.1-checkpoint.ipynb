# %%
name = "Ravi"
age = 18
height = 5.9
is_student = True

print(name)
print(age)
print(height)
print(is_student)


print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# Ravi
# 18
# 5.9
# True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
