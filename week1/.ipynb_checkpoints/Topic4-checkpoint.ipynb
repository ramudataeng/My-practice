# %%
# Topic 4
# Loops
fruits = ["Apple", "Mango", "Orange"]
for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Mango
# Orange

# %%
# Loops cities
city = ["Newyork", "London", "Tokyo", "Delhi"]
for cities in city:
    print(cities)
# Out:
# Newyork
# London
# Tokyo
# Delhi
