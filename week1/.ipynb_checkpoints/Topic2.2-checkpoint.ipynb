# %%
product_name = "Rice"
price = 14.99
stock = 250
is_active = True


print(product_name)
print(price)
print(stock)
print(is_active)

print(type(product_name))
print(type(price))
print(type(stock))
print(type(is_active))
# Out:
# Rice
# 14.99
# 250
# True
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'bool'>
